# %% [markdown]
# ## Set Widget Properties

# %%
from kivy.config import Config
Config.set('graphics', 'fullscreen', '0')
Config.write()
import kivy
from kivy.app import App
from kivy.uix.widget import Widget
from kivy.properties import ObjectProperty
from kivy.lang import Builder


Builder.load_file('inherit.kv')


class MyLayout(Widget):
    pass

class RobotIntfApp(App):
    def build(self):
        return MyLayout()
    
RobotIntfApp().run()
# Out:
# [INFO   ] [Logger      ] Record log in C:\Users\PLASMANT\.kivy\logs\kivy_21-02-17_17.txt
# [INFO   ] [Kivy        ] v2.0.0
# [INFO   ] [Kivy        ] Installed at "C:\Users\PLASMANT\anaconda3\lib\site-packages\kivy\__init__.py"
# [INFO   ] [Python      ] v3.7.7 (default, May  6 2020, 11:45:54) [MSC v.1916 64 bit (AMD64)]
# [INFO   ] [Python      ] Interpreter at "C:\Users\PLASMANT\anaconda3\python.exe"
# [INFO   ] [Factory     ] 186 symbols loaded
# [INFO   ] [Image       ] Providers: img_tex, img_dds, img_sdl2, img_pil (img_ffpyplayer ignored)
# [INFO   ] [Window      ] Provider: sdl2
# [INFO   ] [GL          ] Using the "OpenGL" graphics system
# [INFO   ] [GL          ] GLEW initialization succeeded
# [INFO   ] [GL          ] Backend used <glew>
# [INFO   ] [GL          ] OpenGL version <b'4.5.0 - Build 24.20.100.6292'>
# [INFO   ] [GL          ] OpenGL vendor <b'Intel'>
# [INFO   ] [GL          ] OpenGL renderer <b'Intel(R) HD Graphics 620'>
# [INFO   ] [GL          ] OpenGL parsed version: 4, 5
# [INFO   ] [GL          ] Shading version <b'4.50 - Build 24.20.100.6292'>
# [INFO   ] [GL          ] Texture max size <16384>
# [INFO   ] [GL          ] Texture max units <32>
# [INFO   ] [Window      ] auto add sdl2 input provider
# [INFO   ] [Window      ] virtual keyboard not allowed, single mode, not docked
# [INFO   ] [Text        ] Provider: sdl2
# [INFO   ] [Base        ] Start application main loop
# [INFO   ] [GL          ] NPOT texture support is available
# [INFO   ] [Base        ] Leaving application in progress...

# %% [markdown]
# ## Box Layout

# %%
from kivy.config import Config
Config.set('graphics', 'fullscreen', '0')
Config.write()
import kivy
from kivy.app import App
from kivy.uix.widget import Widget
from kivy.properties import ObjectProperty
from kivy.lang import Builder


Builder.load_file('boxlayout.kv')


class MyLayout(Widget):
    pass

class RobotIntfApp(App):
    def build(self):
        return MyLayout()
    
RobotIntfApp().run()
# Out:
# [INFO   ] [Logger      ] Record log in C:\Users\PLASMANT\.kivy\logs\kivy_21-02-17_10.txt
# [INFO   ] [Kivy        ] v2.0.0
# [INFO   ] [Kivy        ] Installed at "C:\Users\PLASMANT\anaconda3\lib\site-packages\kivy\__init__.py"
# [INFO   ] [Python      ] v3.7.7 (default, May  6 2020, 11:45:54) [MSC v.1916 64 bit (AMD64)]
# [INFO   ] [Python      ] Interpreter at "C:\Users\PLASMANT\anaconda3\python.exe"
# [INFO   ] [Factory     ] 186 symbols loaded
# [INFO   ] [Image       ] Providers: img_tex, img_dds, img_sdl2, img_pil (img_ffpyplayer ignored)
# [INFO   ] [Window      ] Provider: sdl2
# [INFO   ] [GL          ] Using the "OpenGL" graphics system
# [INFO   ] [GL          ] GLEW initialization succeeded
# [INFO   ] [GL          ] Backend used <glew>
# [INFO   ] [GL          ] OpenGL version <b'4.5.0 - Build 24.20.100.6292'>
# [INFO   ] [GL          ] OpenGL vendor <b'Intel'>
# [INFO   ] [GL          ] OpenGL renderer <b'Intel(R) HD Graphics 620'>
# [INFO   ] [GL          ] OpenGL parsed version: 4, 5
# [INFO   ] [GL          ] Shading version <b'4.50 - Build 24.20.100.6292'>
# [INFO   ] [GL          ] Texture max size <16384>
# [INFO   ] [GL          ] Texture max units <32>
# [INFO   ] [Window      ] auto add sdl2 input provider
# [INFO   ] [Window      ] virtual keyboard not allowed, single mode, not docked
# [INFO   ] [Text        ] Provider: sdl2
# [INFO   ] [Base        ] Start application main loop
# [INFO   ] [GL          ] NPOT texture support is available
# [INFO   ] [Base        ] Leaving application in progress...

# %% [markdown]
# ## GridLayout

# %%
from kivy.config import Config
Config.set('graphics', 'fullscreen', '0')
Config.write()
import kivy
from kivy.app import App
from kivy.uix.widget import Widget
from kivy.properties import ObjectProperty
from kivy.lang import Builder


Builder.load_file('controls.kv')


class MyGridLayout(Widget):
    name=ObjectProperty(None)
    pizza=ObjectProperty(None)
    
    
    
    
    def press(self):
        name=self.name.text
        pizza=self.pizza.text
        
        #print to screen
        self.add_widget(Label(text=f'Hello {name}, you like {pizza} pizza!'))
        
        #Clear input boxes
        self.name.text=""
        self.pizza.text=""

class RobotIntfApp(App):
    def build(self):
        return MyGridLayout()
    
RobotIntfApp().run()
# Out:
# [INFO   ] [Logger      ] Record log in C:\Users\PLASMANT\.kivy\logs\kivy_21-02-17_2.txt
# [INFO   ] [Kivy        ] v2.0.0
# [INFO   ] [Kivy        ] Installed at "C:\Users\PLASMANT\anaconda3\lib\site-packages\kivy\__init__.py"
# [INFO   ] [Python      ] v3.7.7 (default, May  6 2020, 11:45:54) [MSC v.1916 64 bit (AMD64)]
# [INFO   ] [Python      ] Interpreter at "C:\Users\PLASMANT\anaconda3\python.exe"
# [INFO   ] [Factory     ] 186 symbols loaded
# [INFO   ] [Image       ] Providers: img_tex, img_dds, img_sdl2, img_pil (img_ffpyplayer ignored)
# [INFO   ] [Window      ] Provider: sdl2
# [INFO   ] [GL          ] Using the "OpenGL" graphics system
# [INFO   ] [GL          ] GLEW initialization succeeded
# [INFO   ] [GL          ] Backend used <glew>
# [INFO   ] [GL          ] OpenGL version <b'4.5.0 - Build 24.20.100.6292'>
# [INFO   ] [GL          ] OpenGL vendor <b'Intel'>
# [INFO   ] [GL          ] OpenGL renderer <b'Intel(R) HD Graphics 620'>
# [INFO   ] [GL          ] OpenGL parsed version: 4, 5
# [INFO   ] [GL          ] Shading version <b'4.50 - Build 24.20.100.6292'>
# [INFO   ] [GL          ] Texture max size <16384>
# [INFO   ] [GL          ] Texture max units <32>
# [INFO   ] [Window      ] auto add sdl2 input provider
# [INFO   ] [Window      ] virtual keyboard not allowed, single mode, not docked
# [INFO   ] [Text        ] Provider: sdl2
# [INFO   ] [Base        ] Start application main loop
# [INFO   ] [GL          ] NPOT texture support is available
# [INFO   ] [Base        ] Leaving application in progress...

# %%
from kivy.config import Config
Config.set('graphics', 'fullscreen', '0')
Config.write()
import kivy
from kivy.app import App
from kivy.uix.label import Label
from kivy.uix.gridlayout import GridLayout
from kivy.uix.textinput import TextInput
from kivy.uix.button import Button
from kivy.uix.widget import Widget

class MyGridLayout(Widget):
    
    
    
    #initialize infinite keywords
    def __init__(self, **kwargs):
        #call grid layout constructor
        super(MyGridLayout, self).__init__(**kwargs)  
        #set columns
        self.cols=1
        self.row_force_default=True
        row_default_height=120,
        col_force_default=True,
        col_default_width=200
        #create second gridlayout
        self.top_grid=GridLayout(
            row_force_default=True,
            row_default_height=40,
            col_force_default=True,
            col_default_width=200
        )
        self.top_grid.cols=2
        
        #add widgets1
        self.top_grid.add_widget(Label(text="Name: "))
        self.name=TextInput(multiline=True)
        self.top_grid.add_widget(self.name)
        
                            
        #add widgets2
        self.top_grid.add_widget(Label(text="Favorite Pizza: "))
        #add input box
        self.pizza=TextInput(multiline=False)
        self.top_grid.add_widget(self.pizza)
        
        #add top_grid to our app
        self.add_widget(self.top_grid)
        
        #create submit button
        self.submit=Button(text="Submit", font_size=32,
                           size_hint_y=None,
                           height=50,
                           size_hint_x=None,
                           width=200
                          )
        #bind button to command
        self.submit.bind(on_press=self.press)
        self.add_widget(self.submit)
    
    def press(self,instance):
        name=self.name.text
        pizza=self.pizza.text
        
        #print to terminal
        #print(f'Hello {name}, you like {pizza} pizza!')
        #print to screen
        self.add_widget(Label(text=f'Hello {name}, you like {pizza} pizza!'))
        
        #Clear input boxes
        self.name.text=""
        self.pizza.text=""
my.kv
class MyApp(App):
    def build(self):
        return MyGridLayout()
    
MyApp().run()
# Out:
# [INFO   ] [Logger      ] Record log in C:\Users\PLASMANT\.kivy\logs\kivy_21-02-16_41.txt
# [INFO   ] [Kivy        ] v2.0.0
# [INFO   ] [Kivy        ] Installed at "C:\Users\PLASMANT\anaconda3\lib\site-packages\kivy\__init__.py"
# [INFO   ] [Python      ] v3.7.7 (default, May  6 2020, 11:45:54) [MSC v.1916 64 bit (AMD64)]
# [INFO   ] [Python      ] Interpreter at "C:\Users\PLASMANT\anaconda3\python.exe"
# [INFO   ] [Factory     ] 186 symbols loaded
# [INFO   ] [Image       ] Providers: img_tex, img_dds, img_sdl2, img_pil (img_ffpyplayer ignored)
# [INFO   ] [Text        ] Provider: sdl2
# [INFO   ] [Window      ] Provider: sdl2
# [INFO   ] [GL          ] Using the "OpenGL" graphics system
# [INFO   ] [GL          ] GLEW initialization succeeded
# [INFO   ] [GL          ] Backend used <glew>
# [INFO   ] [GL          ] OpenGL version <b'4.5.0 - Build 24.20.100.6292'>
# [INFO   ] [GL          ] OpenGL vendor <b'Intel'>
# [INFO   ] [GL          ] OpenGL renderer <b'Intel(R) HD Graphics 620'>
# [INFO   ] [GL          ] OpenGL parsed version: 4, 5
# [INFO   ] [GL          ] Shading version <b'4.50 - Build 24.20.100.6292'>
# [INFO   ] [GL          ] Texture max size <16384>
# [INFO   ] [GL          ] Texture max units <32>
# [INFO   ] [Window      ] auto add sdl2 input provider
# [INFO   ] [Window      ] virtual keyboard not allowed, single mode, not docked
# [INFO   ] [Base        ] Start application main loop
# [INFO   ] [GL          ] NPOT texture support is available
# [INFO   ] [Base        ] Leaving application in progress...

# %%
from kivy.config import Config
Config.set('graphics', 'fullscreen', '0')
Config.write()
import kivy
from kivy.app import App
from kivy.uix.label import Label

class MyApp(App):
    def build(self):
        return Label(text="Hello")
# Out:
# [INFO   ] [Logger      ] Record log in C:\Users\PLASMANT\.kivy\logs\kivy_21-02-16_16.txt
# [INFO   ] [Kivy        ] v2.0.0
# [INFO   ] [Kivy        ] Installed at "C:\Users\PLASMANT\anaconda3\lib\site-packages\kivy\__init__.py"
# [INFO   ] [Python      ] v3.7.7 (default, May  6 2020, 11:45:54) [MSC v.1916 64 bit (AMD64)]
# [INFO   ] [Python      ] Interpreter at "C:\Users\PLASMANT\anaconda3\python.exe"
# [INFO   ] [Factory     ] 186 symbols loaded
# [INFO   ] [Image       ] Providers: img_tex, img_dds, img_sdl2, img_pil (img_ffpyplayer ignored)
# [INFO   ] [Text        ] Provider: sdl2

# %%
from kivy.config import Config
Config.set('graphics', 'fullscreen', '0')
Config.write()
import kivy
from kivy.app import App
#all the following can be removed because we are using my.kv file instead
from kivy.uix.label import Label
from kivy.uix.gridlayout import GridLayout
from kivy.uix.textinput import TextInput
from kivy.uix.button import Button

class MyGridLayout(GridLayout):
    #initialize infinite keywords
    def __init__(self, **kwargs):
        #call grid layout constructor
        super(MyGridLayout, self).__init__(**kwargs)  
        #set columns
        self.cols=1
        
        #create second gridlayout
        self.top_grid=GridLayout()
        self.top_grid.cols=2
        
        #add widgets1
        self.top_grid.add_widget(Label(text="Name: "))
        self.name=TextInput(multiline=True)
        self.top_grid.add_widget(self.name)
        
                            
        #add widgets2
        self.top_grid.add_widget(Label(text="Favorite Pizza: "))
        #add input box
        self.pizza=TextInput(multiline=False)
        self.top_grid.add_widget(self.pizza)
        
        #add top_grid to our app
        self.add_widget(self.top_grid)
        
        #create submit button
        self.submit=Button(text="Submit", font_size=32)
        #bind button to command
        self.submit.bind(on_press=self.press)
        self.add_widget(self.submit)
    
    def press(self,instance):
        name=self.name.text
        pizza=self.pizza.text
        
        #print to terminal
        #print(f'Hello {name}, you like {pizza} pizza!')
        #print to screen
        self.add_widget(Label(text=f'Hello {name}, you like {pizza} pizza!'))
        
        #Clear input boxes
        self.name.text=""
        self.pizza.text=""
class MyApp(App):
    def build(self):
        return MyGridLayout()
    
MyApp().run()
